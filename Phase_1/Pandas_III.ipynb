# %% [markdown]
# # Pandas III
#
# _October 29, 2020_
#
# Agenda today:
# - Statistics in Pandas
# - Groupby in Pandas
# - Stacking & Unstacking

# %% [markdown]
# # Part I. Statistics in Pandas
# Pandas allow us to calculate various summary statistics for the dataframe, such as mean, variance, and other descriptive statistics measurements. Let's see some examples.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", 100000)
pd.set_option("display.max_rows", 30)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#check the info
df.groupby('continent')['country'].value_counts()
# Out:
# continent  country
# AF         Algeria         1
#            Angola          1
#            Benin           1
#            Botswana        1
#            Burkina Faso    1
#                           ..
# SA         Paraguay        1
#            Peru            1
#            Suriname        1
#            Uruguay         1
#            Venezuela       1
# Name: country, Length: 170, dtype: int64

# %%
# calculate mean beer_servings
df.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# calculate summary statistics for all measurements
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# how could we view summary statistics for categorical variable?
df.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# reviewing subsetting and selecting - select the countries on continent AF
df.continent.value_counts(normalize=True)
# Out:
# AF    0.311765
# EU    0.264706
# AS    0.258824
# OC    0.094118
# SA    0.070588
# Name: continent, dtype: float64

# %% [markdown]
# ## Part II. Pandas Groupby
# Groupby methods in Pandas allow you to aggregate data and perform operations on them. The method can be summarized as split-apply-combine. The groupby function allow us to split the dataframe into _groups_, apply operations on them, and aggregate a final result. Let's look at some examples.

# %%
# review summary statistics for each continent
df.groupby('continent').describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings                                             \
#              max           count        mean        std   min    25%    50%
# continent
# AF         376.0            53.0   16.339623  28.102794   0.0   1.00    3.0
# AS         247.0            44.0   60.840909  84.362160   0.0   1.00   16.0
# EU         361.0            45.0  132.555556  77.589115   0.0  81.00  122.0
# OC         306.0            16.0   58.437500  70.504817   0.0  18.00   37.0
# SA         333.0            12.0  114.750000  77.077440  25.0  65.75  108.5
#
#                          wine_servings                                    \
#               75%    max         count        mean        std  min   25%
# continent
# AF          19.00  152.0          53.0   16.264151  38.846419  0.0   1.0
# AS          98.00  326.0          44.0    9.068182  21.667034  0.0   0.0
# EU         173.00  373.0          45.0  142.222222  97.421738  0.0  59.0
# OC          65.25  254.0          16.0   35.625000  64.555790  0.0   1.0
# SA         148.75  302.0          12.0   62.416667  88.620189  1.0   3.0
#
#                                 total_litres_of_pure_alcohol            \
#              50%     75%    max                        count      mean
# continent
# AF           2.0   13.00  233.0                         53.0  3.007547
# AS           1.0    8.00  123.0                         44.0  2.170455
# EU         128.0  195.00  370.0                         45.0  8.617778
# OC           8.5   23.25  212.0                         16.0  3.381250
# SA          12.0   98.50  221.0                         12.0  6.308333
#
#
#                 std  min   25%    50%     75%   max
# continent
# AF         2.647557  0.0  0.70   2.30   4.700   9.1
# AS         2.770239  0.0  0.10   1.20   2.425  11.5
# EU         3.358455  0.0  6.60  10.00  10.900  14.4
# OC         3.345688  0.0  1.00   1.75   6.150  10.4
# SA         1.531166  3.8  5.25   6.85   7.375   8.3

# %%
# which continent drinks more beer on average?
df.groupby('continent')['beer_servings'].max().sort_values(ascending=False)
# Out:
# continent
# AF    376
# EU    361
# SA    333
# OC    306
# AS    247
# Name: beer_servings, dtype: int64

# %%
# exercise - which continent drinks more beer than wine?
x = df.groupby('continent').sum()
x[x.beer_servings > x.spirit_servings].index.values
# Out:
# array(['AF', 'EU', 'OC', 'SA'], dtype=object)

# %%
# you can also groupby multiple columns - which will result in a hierarchical index. 

# read in df from this url https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user

# and set the index as user_id
occupations = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',
                         sep='|')

# %%
occupations.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
# calculate the mean age per occupation
occupations.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# for each combination of sex and occupation, show the mean age, assigned it to group by age
group_by_age = occupations.groupby(['gender','occupation'])['age'].mean()

# %%
group_by_age
# Out:
# gender  occupation
# F       administrator    40.638889
#         artist           30.307692
#         educator         39.115385
#         engineer         29.500000
#         entertainment    31.000000
#                            ...
# M       salesman         38.555556
#         scientist        36.321429
#         student          22.669118
#         technician       32.961538
#         writer           35.346154
# Name: age, Length: 41, dtype: float64

# %%
# exercise - for each occupation, calculate the percentage of female and sort it from high to low
occupations.groupby('occupation')['gender'].value_counts()
# Out:
# occupation     gender
# administrator  M         43
#                F         36
# artist         M         15
#                F         13
# doctor         M          7
#                          ..
# student        F         60
# technician     M         26
#                F          1
# writer         M         26
#                F         19
# Name: gender, Length: 41, dtype: int64

# %%
occupations.gender.count()
# Out:
# 943

# %%
# if you want all the levels to be together, just sort the values
occupations.groupby('occupation')['gender'].value_counts(normalize=True)[:,'F']
# Out:
# occupation
# administrator    0.455696
# artist           0.464286
# educator         0.273684
# engineer         0.029851
# entertainment    0.111111
# executive        0.093750
# healthcare       0.687500
# homemaker        0.857143
# lawyer           0.166667
# librarian        0.568627
# marketing        0.384615
# none             0.444444
# other            0.342857
# programmer       0.090909
# retired          0.071429
# salesman         0.250000
# scientist        0.096774
# student          0.306122
# technician       0.037037
# writer           0.422222
# Name: gender, dtype: float64

# %%
df['horsepower'].apply(lambda x: x if type(x) == int else 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'horsepower'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-941bb75b3aea> in <module>()
# ----> 1 df['horsepower'].apply(lambda x: x if type(x) == int else 0)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'horsepower'

# %% [markdown]
# ## Part III. Stacking & Unstack
# Stack and unstack in Pandas provide a way for us to easily manipulate the format of our dataframes. As we see above, the row index can have hierarchy - where one level of index is nested under another. This structure can happen for columns as well. If we want to manipulate the structure of rows and columns, we need to learn stack() and unstack().
#
# **Stack()**
#
# <img src = 'stack.png' width = 450>
#
# **Unstack()**
#
# <img src = 'unstack.png' width = 450>
#
# What you you think is happening here?

# %%
group_by_age
# Out:
# gender  occupation
# F       administrator    40.638889
#         artist           30.307692
#         educator         39.115385
#         engineer         29.500000
#         entertainment    31.000000
#                            ...
# M       salesman         38.555556
#         scientist        36.321429
#         student          22.669118
#         technician       32.961538
#         writer           35.346154
# Name: age, Length: 41, dtype: float64

# %%
pd.DataFrame(group_by_age).unstack()
# Out:
#                      age                                            \
# occupation administrator     artist     doctor   educator engineer
# gender
# F              40.638889  30.307692        NaN  39.115385     29.5
# M              37.162791  32.333333  43.571429  43.101449     36.6
#
#                                                                             \
# occupation entertainment  executive healthcare  homemaker lawyer librarian
# gender
# F                   31.0  44.000000  39.818182  34.166667   39.5      40.0
# M                   29.0  38.172414  45.400000  23.000000   36.2      40.0
#
#                                                                         \
# occupation marketing  none      other programmer    retired   salesman
# gender
# F             37.200  36.5  35.472222  32.166667  70.000000  27.000000
# M             37.875  18.6  34.028986  33.216667  62.538462  38.555556
#
#
# occupation  scientist    student technician     writer
# gender
# F           28.333333  20.750000  38.000000  37.631579
# M           36.321429  22.669118  32.961538  35.346154

# %%
# turn group by age from long to wide

# %%
# play around with stacking and unstacking for the above datasets
pd.DataFrame(df.stack())
# Out:
#                                             0
# 0   country                       Afghanistan
#     beer_servings                           0
#     spirit_servings                         0
#     wine_servings                           0
#     total_litres_of_pure_alcohol            0
# ...                                       ...
# 192 beer_servings                          64
#     spirit_servings                        18
#     wine_servings                           4
#     total_litres_of_pure_alcohol          4.7
#     continent                              AF
#
# [1135 rows x 1 columns]

# %% [markdown]
# #### Optional exercises & level up - the Adult dataset

# %%
# read in the adults dataset 
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
adults = pd.read_csv(url,header=None)

# %%
adults
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                        6               7       8        9      10  11  12  \
# 0            Adm-clerical   Not-in-family   White     Male   2174   0  40
# 1         Exec-managerial         Husband   White     Male      0   0  13
# 2       Handlers-cleaners   Not-in-family   White     Male      0   0  40
# 3       Handlers-cleaners         Husband   Black     Male      0   0  40
# 4          Prof-specialty            Wife   Black   Female      0   0  40
# ...                   ...             ...     ...      ...    ...  ..  ..
# 32556        Tech-support            Wife   White   Female      0   0  38
# 32557   Machine-op-inspct         Husband   White     Male      0   0  40
# 32558        Adm-clerical       Unmarried   White   Female      0   0  40
# 32559        Adm-clerical       Own-child   White     Male      0   0  20
# 32560     Exec-managerial            Wife   White   Female  15024   0  40
#
#                    13      14
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3       United-States   <=50K
# 4                Cuba   <=50K
# ...               ...     ...
# 32556   United-States   <=50K
# 32557   United-States    >50K
# 32558   United-States   <=50K
# 32559   United-States   <=50K
# 32560   United-States    >50K
#
# [32561 rows x 15 columns]

# %%
adults[14].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: 14, dtype: int64

# %%
adults.columns = [0, 1, 2, 3, 4, 5, 6, 7, 'race', 'gender', 10, 11, 12, 13, 'income','ib']

# %%
# create a column called income binary, 1 if income >50k 0 otherwise
adults['ib'] = adults[14].apply(lambda x: 0 if x == ' <=50K' else 1)

# %%
adults
# Out:
#         0                  1       2            3   4                    5  \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                         6               7    race   gender     10  11  12  \
# 0            Adm-clerical   Not-in-family   White     Male   2174   0  40
# 1         Exec-managerial         Husband   White     Male      0   0  13
# 2       Handlers-cleaners   Not-in-family   White     Male      0   0  40
# 3       Handlers-cleaners         Husband   Black     Male      0   0  40
# 4          Prof-specialty            Wife   Black   Female      0   0  40
# ...                   ...             ...     ...      ...    ...  ..  ..
# 32556        Tech-support            Wife   White   Female      0   0  38
# 32557   Machine-op-inspct         Husband   White     Male      0   0  40
# 32558        Adm-clerical       Unmarried   White   Female      0   0  40
# 32559        Adm-clerical       Own-child   White     Male      0   0  20
# 32560     Exec-managerial            Wife   White   Female  15024   0  40
#
#                    13  income  ib
# 0       United-States   <=50K   0
# 1       United-States   <=50K   0
# 2       United-States   <=50K   0
# 3       United-States   <=50K   0
# 4                Cuba   <=50K   0
# ...               ...     ...  ..
# 32556   United-States   <=50K   0
# 32557   United-States    >50K   1
# 32558   United-States   <=50K   0
# 32559   United-States   <=50K   0
# 32560   United-States    >50K   1
#
# [32561 rows x 16 columns]

# %%
# explore the racial distribution of income (you should use stack or unstack here)
adults.groupby(['race','income']).count()
# this show allows us to calculate the proportion of people who earned more than 50k by race
# Out:
#                                 0      1      2      3      4      5      6  \
# race                income
#  Amer-Indian-Eskimo  <=50K    275    275    275    275    275    275    275
#                      >50K      36     36     36     36     36     36     36
#  Asian-Pac-Islander  <=50K    763    763    763    763    763    763    763
#                      >50K     276    276    276    276    276    276    276
#  Black               <=50K   2737   2737   2737   2737   2737   2737   2737
#                      >50K     387    387    387    387    387    387    387
#  Other               <=50K    246    246    246    246    246    246    246
#                      >50K      25     25     25     25     25     25     25
#  White               <=50K  20699  20699  20699  20699  20699  20699  20699
#                      >50K    7117   7117   7117   7117   7117   7117   7117
#
#                                 7  gender     10     11     12     13     ib
# race                income
#  Amer-Indian-Eskimo  <=50K    275     275    275    275    275    275    275
#                      >50K      36      36     36     36     36     36     36
#  Asian-Pac-Islander  <=50K    763     763    763    763    763    763    763
#                      >50K     276     276    276    276    276    276    276
#  Black               <=50K   2737    2737   2737   2737   2737   2737   2737
#                      >50K     387     387    387    387    387    387    387
#  Other               <=50K    246     246    246    246    246    246    246
#                      >50K      25      25     25     25     25     25     25
#  White               <=50K  20699   20699  20699  20699  20699  20699  20699
#                      >50K    7117    7117   7117   7117   7117   7117   7117

# %%
adults.income.count()
# Out:
# 32561

# %%
lst[-1]
# Out:
# 6

# %%
# explore the gender distribution of income (you should use stack or unstack here)
adults.groupby(['sex'])['income'].value_counts()
adults.groupby(['race'])['income'].value_counts(normalize=True).unstack()
# this show allows us to calculate the proportion of people who earned more than 50k by gender
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-0537fbced58c> in <module>()
#       1 # explore the gender distribution of income (you should use stack or unstack here)
# ----> 2 adults.groupby(['sex'])['income'].value_counts()
#       3 adults.groupby(['race'])['income'].value_counts(normalize=True).unstack()
#       4 # this show allows us to calculate the proportion of people who earned more than 50k by gender
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'sex'
